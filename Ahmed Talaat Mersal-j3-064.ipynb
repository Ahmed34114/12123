# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Assessment for comptencey ECU-ITAI-1-04

# %% [markdown]
# # name:Ahmed Talaat Mersal

# %% [markdown]
# # junior:j3

# %% [markdown]
# # First learning outcome

# %% [markdown]
# 1. uses a software to convert between files from mp3 to wav

# %%
# !pip install pydub
import subprocess
from pydub import AudioSegment

input_file = r"C:\Users\j0223064\Desktop\New folder (2)\typical-trap-loop-140bpm-129880.mp3"
output_file = r"C:\Users\j0223064\Desktop\New folder (2)\sample_960x400_ocean_with_audio.mav"
audio = AudioSegment.from_mp3(input_file)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 7
#       5 input_file = r"C:\Users\j0223064\Desktop\New folder (2)\typical-trap-loop-140bpm-129880.mp3"
#       6 output_file = r"C:\Users\j0223064\Desktop\New folder (2)\sample_960x400_ocean_with_audio.mav"
# ----> 7 audio = AudioSegment.from_mp3(input_file)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pydub\audio_segment.py:796, in AudioSegment.from_mp3(cls, file, parameters)
#     794 @classmethod
#     795 def from_mp3(cls, file, parameters=None):
# --> 796     return cls.from_file(file, 'mp3', parameters=parameters)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pydub\audio_segment.py:728, in AudioSegment.from_file(cls, file, format, codec, parameters, start_second, duration, **kwargs)
# ...

# %% [markdown]
# 2. uses a software to convert between files from MP4 to avi

# %%
# !pip install pylabel
from pylabel import importer
a=importer.importMp4(r"C:\Users\j0223064\Desktop\New folder (2)\sample_960x400_ocean_with_audio - Copy.mp4")
x.ExportToAvi(r"C:\Users\j0223064\Desktop\New folder (2)\sample_960x400_ocean_with_audio.avi")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 3
#       1 get_ipython().system('pip install pylabel')
#       2 from pylabel import importer
# ----> 3 a=importer.importMp4(r"C:\Users\j0223064\Desktop\New folder (2)\sample_960x400_ocean_with_audio - Copy.mp4")
#       4 x.ExportToAvi(r"C:\Users\j0223064\Desktop\New folder (2)\sample_960x400_ocean_with_audio.avi")
#
# AttributeError: module 'pylabel.importer' has no attribute 'importMp4'

# %% [markdown]
# 3. 	uses a software to convert between files from png to jpg format

# %%
# !pip install pylabel
from pylabel import importer
a=importer.importpng(r"C:\Users\j0223064\Desktop\New folder (2)\image\Screenshot 2024-02-20 155049.png")
x.ExportTojpg(r"C:\Users\j0223064\Desktop\New folder (2)\image\Screenshot 2024-02-20 155253.jpg")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 3
#       1 get_ipython().system('pip install pylabel')
#       2 from pylabel import importer
# ----> 3 a=importer.importpng(r"C:\Users\j0223064\Desktop\New folder (2)\image\Screenshot 2024-02-20 155049.png")
#       4 x.ExportTojpg(r"C:\Users\j0223064\Desktop\New folder (2)\image\Screenshot 2024-02-20 155253.jpg")
#
# AttributeError: module 'pylabel.importer' has no attribute 'importpng'

# %% [markdown]
# 4. returns the following statement once in XML format:
# {"data”:{
#            “a”:5,
#            ”b”:8,
#            ”c”:[6,7,9]
#            }
# }

# %%
{
    "fruit": ["Apple"],
    "size": ["Large"],
    "color": ["Red"]
}
# Out:
# {'fruit': ['Apple'], 'size': ['Large'], 'color': ['Red']}

# %% [markdown]
# # Second learning outcome

# %% [raw]
# 1. wrote a code to convert data format from Pascal VOC to COCO

# %%
# !pip install pylabel
from pylabel import importer
df=importer.importVOC(r"C:\Users\j0223064\Desktop\SCREN\New folder\Screenshot 2024-02-20 155026.xml")
df.exportToCoco(r"C:\Users\j0223064\Desktop\SCREN\New folder\example_1.json")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 3
#       1 get_ipython().system('pip install pylabel')
#       2 from pylabel import importer
# ----> 3 df=importer.importVOC(r"C:\Users\j0223064\Desktop\SCREN\New folder\Screenshot 2024-02-20 155026.xml")
#       4 df.exportToCoco(r"C:\Users\j0223064\Desktop\SCREN\New folder\example_1.json")
#
# AttributeError: module 'pylabel.importer' has no attribute 'importVOC'

# %% [markdown]
# 2. 	wrote code to convert data format from COCO to Pascal VOC

# %%
# !pip install pylabel
from pylabel import importer
a=importer.importCoco(r"C:\Users\j0223064\Desktop\New folder (2)\example_1.json")
x.ExportToPascalVOC(r"C:\Users\j0223064\Desktop\New folder (2)\example_1.xml")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 3
#       1 get_ipython().system('pip install pylabel')
#       2 from pylabel import importer
# ----> 3 a=importer.importCoco(r"C:\Users\j0223064\Desktop\New folder (2)\example_1.json")
#       4 x.ExportToPascalVOC(r"C:\Users\j0223064\Desktop\New folder (2)\example_1.xml")
#
# AttributeError: module 'pylabel.importer' has no attribute 'importCoco'

# %% [markdown]
# 3. wrote code to convert data format from COCO to YOLO

# %%
# !pip install pylabel
from pylabel import importer
a=importer.importCoco(r"C:\Users\j0223064\Desktop\New folder (2)\example_1.json")
x.ExportToYOLO(r"C:\Users\j0223064\Desktop\New folder (2)\example_1.xml")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 3
#       1 get_ipython().system('pip install pylabel')
#       2 from pylabel import importer
# ----> 3 a=importer.importCoco(r"C:\Users\j0223064\Desktop\New folder (2)\example_1.json")
#       4 x.ExportToYOLO(r"C:\Users\j0223064\Desktop\New folder (2)\example_1.xml")
#
# AttributeError: module 'pylabel.importer' has no attribute 'importCoco'

# %% [markdown]
# 3. wrote code to convert data format from YOLO to Pascal VOC

# %%
# !pip install pylabel
from pylabel import importer
a=importer.importYOLO(r"C:\Users\j0223064\Desktop\New folder (2)\example_1.json")
x.ExportToPascalVOC(r"C:\Users\j0223064\Desktop\New folder (2)\example_1.xml")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 3
#       1 get_ipython().system('pip install pylabel')
#       2 from pylabel import importer
# ----> 3 a=importer.importYOLO(r"C:\Users\j0223064\Desktop\New folder (2)\example_1.json")
#       4 x.ExportToPascalVOC(r"C:\Users\j0223064\Desktop\New folder (2)\example_1.xml")
#
# AttributeError: module 'pylabel.importer' has no attribute 'importYOLO'

# %% [markdown]
# # Third learning outcome

# %% [markdown]
# 1. Downloads the appropriate tool for viewing and modifying data forms
# provide screenshot for the tool you will use

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Uses a suitable tool that makes Annotation for the attached photo collection
# COCO format

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. collection attached to the YOLO format, provide screenshot for the yolo text file from inside

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. Uses a suitable tool that makes Annotation for the photo collection attached to Pascal VOC format

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. Makes sure of the accuracy of Annotation, provide screen shot for labeled image

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Prepared By: Eng. Abdelrahman Mustafa saber
